# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import resultcomp
import pandas as pd

# %%
start, end = "20200327_203441", "20200330_120427"
directories= ['20200327_191513', '20200330_120427', '20200327_194509']

# %%
snational, seast, swest = resultcomp.read_results(start=start, end=end, directories=directories)

# %%
_ = resultcomp.plot_scores(snational, seast, swest)

# %%
_ = resultcomp.plot_score_summary(snational, seast, swest)

# %%
seast
# Out:
#                                         score  sampers_weight  twitter_weight
# quantile            run_id
# (-0.001, 3.211]     20200327_191513  0.016887    6.803014e-01    2.232408e-01
# (3.211, 5.192]      20200327_191513  0.204933    7.105888e-02    1.050814e-01
# (5.192, 6.939]      20200327_191513  0.271330    4.137872e-02    6.713642e-02
# (6.939, 8.647]      20200327_191513  0.596346    2.712395e-02    4.751448e-02
# (8.647, 10.313]     20200327_191513  0.492549    2.320578e-02    3.877919e-02
# ...                                       ...             ...             ...
# (277.455, 291.861]  20200327_194509  0.999969    2.727059e-07    5.376193e-05
# (291.861, 312.377]  20200327_194509  0.999988    1.784666e-07    3.404780e-05
# (312.377, 348.792]  20200327_194509  0.999993    7.081628e-08    2.691498e-05
# (348.792, 444.055]  20200327_194509  0.999999    1.027642e-09    1.180752e-05
# (444.055, 1442.945] 20200327_194509  1.000000    3.211192e-13    5.443288e-07
#
# [300 rows x 3 columns]

# %%
dms = resultcomp.read_distance_metrics(directories=directories)

# %%
_ = resultcomp.plot_distance_metrics(dms)

# %%
import sampers
import importlib
import matplotlib.pyplot as plt
importlib.reload(sampers)
region = 'east'

# %%
shp = sampers.read_shp(sampers.shps[region])
shp
# Out:
#         zone  FIRST_LÃ¤n  FIRST_KO_1  FIRST_KNKO  \
# 0          0           0        None           0
# 1     700611           6    VAGGERYD         665
# 2     700612           6       ANEBY         604
# 3     700613           6    NÃSSJÃ         682
# 4     700614           6     GNOSJÃ         617
# ...      ...         ...         ...         ...
# 3033  991833          21    BOLLNÃS        2183
# 3034  991841          21  HUDIKSVALL        2184
# 3035  991842          21  HUDIKSVALL        2184
# 3036  991843          21  HUDIKSVALL        2184
# 3037  991844          21  HUDIKSVALL        2184
#
#                                                geometry
# 0     MULTIPOLYGON (((297619.654 6068847.281, 297615...
# 1     POLYGON ((473565.617 6440467.882, 473569.127 6...
# 2     POLYGON ((499095.672 6445343.779, 499111.256 6...
# 3     POLYGON ((493659.743 6407794.202, 493922.178 6...
# 4     POLYGON ((429622.081 6386346.663, 429881.924 6...
# ...                                                 ...
# 3033  POLYGON ((590438.423 6818754.224, 590367.115 6...
# 3034  POLYGON ((556367.389 6899443.143, 556599.791 6...
# 3035  POLYGON ((658174.968 6854585.580, 657593.070 6...
# 3036  POLYGON ((601449.909 6862634.692, 602432.546 6...
# 3037  POLYGON ((620953.958 6860197.929, 620918.527 6...
#
# [3038 rows x 5 columns]

# %%
odm = sampers.read_odm(sampers.odms[region])
odm
# Out:
#           ozone   dzone    work_Bike  business_Bike   other_Bike     work_Car  \
# 0        700611  700611     0.000000       0.000000     0.000000     0.000000
# 1        700611  700612     0.000000       0.000000     0.000000     0.000000
# 2        700611  700613     0.000000       0.000000     0.000000     0.000000
# 3        700611  700614     0.000000       0.000000     0.000000     0.000000
# 4        700611  700715     0.000000       0.000000     0.000000     0.000000
# ...         ...     ...          ...            ...          ...          ...
# 9253759  991844  991833     0.000000       0.000000     0.000000     0.796304
# 9253760  991844  991841     0.000000       0.000000     0.000000     1.981645
# 9253761  991844  991842     0.151370       0.000355     0.648036    40.215000
# 9253762  991844  991843     0.987539       0.017135     2.423075    37.873120
# 9253763  991844  991844  1139.564000      84.683300  1823.002000  1353.002000
#
#          business_Car    other_Car  work_PublicTransport  \
# 0            0.000000     0.000000              0.000000
# 1            0.000000     0.000000              0.000000
# 2            0.000000     0.000000              0.000000
# 3            0.000000     0.000000              0.000000
# 4            0.000000     0.000000              0.000000
# ...               ...          ...                   ...
# 9253759      0.881717     0.770052              0.993191
# 9253760      2.151247    13.806590              0.572170
# 9253761      7.264530    78.887260              1.539540
# 9253762      5.887914    82.807530              4.198044
# 9253763    422.201900  4569.613000              0.000000
#
#          business_PublicTransport  other_PublicTransport  work_Walking  \
# 0                        0.000000               0.000000         0.000
# 1                        0.000000               0.000000         0.000
# 2                        0.000000               0.000000         0.000
# 3                        0.000000               0.000000         0.000
# 4                        0.000000               0.000000         0.000
# ...                           ...                    ...           ...
# 9253759                  0.423163               0.982032         0.000
# 9253760                  0.784277              14.058790         0.000
# 9253761                  4.518525              54.495110         0.000
# 9253762                  2.816242              40.889470         0.000
# 9253763                  0.000000               0.000000      1628.373
#
#          business_Walking  other_Walking         work    business  \
# 0                     0.0           0.00     0.000000    0.000000
# 1                     0.0           0.00     0.000000    0.000000
# 2                     0.0           0.00     0.000000    0.000000
# 3                     0.0           0.00     0.000000    0.000000
# 4                     0.0           0.00     0.000000    0.000000
# ...                   ...            ...          ...         ...
# 9253759               0.0           0.00     1.789495    1.304880
# 9253760               0.0           0.00     2.553815    2.935525
# 9253761               0.0           0.00    41.905910   11.783410
# 9253762               0.0           0.00    43.058703    8.721291
# 9253763               0.0       10323.17  4120.939000  506.885200
#
#                 other         total
# 0            0.000000      0.000000
# 1            0.000000      0.000000
# 2            0.000000      0.000000
# 3            0.000000      0.000000
# 4            0.000000      0.000000
# ...               ...           ...
# 9253759      1.752083      4.846459
# 9253760     27.865380     33.354720
# 9253761    134.030406    187.719726
# 9253762    126.120075    177.900069
# 9253763  16715.785000  21343.609200
#
# [9253764 rows x 18 columns]

# %%
agg_odm = sampers.aggregate_odm(odm)
agg_odm.head()

# %%
geoodm = sampers.merge_odm_shp(agg_odm, shp)
geoodm

# %%
fix, axes = plt.subplots(1,3)
shp.plot(ax = axes[0])
geoodm.plot(ax = axes[1], column='origin')
geoodm.plot(ax = axes[2], column='destination')
